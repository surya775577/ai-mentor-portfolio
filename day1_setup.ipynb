# %% [markdown]
# <a href="https://colab.research.google.com/github/surya775577/ai-mentor-portfolio/blob/main/day1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical progression of skills needed for successful AI projects:
#
# *   **Foundation (Data Infrastructure & Feature Engineering):** The base layers focus on skills related to collecting, storing, cleaning, and transforming raw data into useful features suitable for AI models.
# *   **Core (Model Development):** The mid-tier involves the skills for selecting, training, evaluating, and fine-tuning machine learning and deep learning algorithms.
# *   **Application (Deployment & Operations):** This layer covers integrating trained models into production systems, MLOps, monitoring performance, and maintaining models over time.
# *   **Apex (Business Acumen & Ethics):** The top layer emphasizes understanding the business problem, project impact, stakeholder communication, and ensuring ethical, responsible, and value-driven AI solutions.
